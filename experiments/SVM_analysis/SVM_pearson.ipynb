# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import csv
# %matplotlib inline

# %%
movie_num = pd.read_csv('movie_color1.csv')
movie.head()
# Out:
#    Unnamed: 0  num_critic_for_reviews  duration      gross  num_voted_users  \
# 0           1                     723       178  20.449494           886204
# 1           2                     302       169  19.550159           471220
# 2           3                     602       148  19.114199           275868
# 3           4                     813       164  19.920595          1144337
# 4           5                     462       132  18.106773           212204
#
#    num_user_for_reviews content_rating     budget  imdb_score aspect_ratio  \
# 0                  3054          PG-13  19.283571         7.9    c) Others
# 1                  1238          PG-13  19.519293         7.1    b) 2.35:1
# 2                   994          PG-13  19.316769         6.8    b) 2.35:1
# 3                  2701          PG-13  19.336971         8.5    b) 2.35:1
# 4                   738          PG-13  19.390323         6.6    b) 2.35:1
#
# ...
